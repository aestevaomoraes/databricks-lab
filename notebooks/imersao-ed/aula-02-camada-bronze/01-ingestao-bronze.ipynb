# %%
spark.sql("USE CATALOG voo_bem")
spark.sql("USE SCHEMA bronze")

# %%
spark.sql("SHOW TABLES").display()

# %%
display(dbutils.fs.ls("/Volumes/voo_bem/bronze/arquivos"))

# %%
display(dbutils.fs.ls("/Volumes/voo_bem/bronze/arquivos"))

# %%
display(dbutils.fs.ls("/Volumes/voo_bem/bronze/arquivos/referencias"))

# %%
display(dbutils.fs.ls("/Volumes/voo_bem/bronze/arquivos/vra"))

# %%
df_vra = (
    spark.read
    .option("header", True)
    .option("sep", ";")
    .csv("/Volumes/voo_bem/bronze/arquivos/vra/*.csv")
)

display(df_vra)

# %%
df_vra.printSchema()

# %%
df_vra.count()
